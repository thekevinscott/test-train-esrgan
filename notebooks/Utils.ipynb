# %% [markdown]
# # Utils

# %%
# !pip install pillow ISR numpy tensorflow opencv-python scikit-learn scikit-image matplotlib

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import imageio
sys.path.append('../src')
from utils import *
import pathlib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from PIL import Image
from io import BytesIO
img_path = './sample_images/fundog.jpg'
def show_imageio(im):
    # im = im * 255.0
    # im = im.astype(int)
    # print(im.dtype)
    return Image.fromarray((im * 255).astype(np.uint8))
    
im = imageio.imread(img_path) / 255.0
show_imageio(im)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F0EA401FC50>

# %%
show_imageio(sharpen_image(im, amount=4))
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F0EA401F4A8>

# %%
show_imageio(compress_image(im, quality=1))
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F0EA401F048>

# %%
write_image('foo.png', im)

# %%
import random
random.randint(50, 100)
# Out:
# 58
