# %% [markdown]
# # Utils

# %%
# !pip install pillow ISR numpy tensorflow opencv-python scikit-learn scikit-image matplotlib

# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
import pathlib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from PIL import Image
from io import BytesIO
im = Image.open('./sample_images/fundog.jpg').convert('RGB')
im
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE297480760>

# %%
compress_image(im, quality=1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7FE2974D50A0>

# %%
sharpen_image(im, amount=3)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE2974D5C40>
